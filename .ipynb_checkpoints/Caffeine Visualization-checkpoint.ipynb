# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random

# %%
df = pd.read_csv('./datasets/CaffeineContents.csv')

# %%
df.columns = ['category', 'item', 'caffeine_mg']

# %%
df
# Out:
#                     category  \
# 0        Coffee (180 ml cup)
# 1        Coffee (180 ml cup)
# 2        Coffee (180 ml cup)
# 3        Coffee (180 ml cup)
# 4        Coffee (180 ml cup)
# 5           Tea (180 ml cup)
# 6           Tea (180 ml cup)
# 7           Tea (180 ml cup)
# 8                      Cocoa
# 9                  Chocolate
# 10                 Chocolate
# 11                 Chocolate
# 12  Soft drinks (360 ml can)
# 13  Soft drinks (360 ml can)
# 14  Soft drinks (360 ml can)
# 15  Soft drinks (360 ml can)
# 16  Soft drinks (360 ml can)
# 17  Soft drinks (360 ml can)
# 18  Soft drinks (360 ml can)
# 19  Medications (per tablet)
# 20  Medications (per tablet)
# 21  Medications (per tablet)
# 22  Medications (per tablet)
# 23  Medications (per tablet)
# 24  Medications (per tablet)
# 25  Medications (per tablet)
# 26  Medications (per tablet)
# 27             Energy drinks
# 28             Energy drinks
# 29             Energy drinks
# 30             Energy drinks
# 31             Energy drinks
# 32             Energy drinks
# 33             Energy drinks
# 34             Energy drinks
# 35             Energy drinks
# 36             Energy drinks
# 37             Energy drinks
# 38             Energy drinks
# 39             Energy drinks
# 40             Energy drinks
# 41             Energy drinks
# 42             Energy drinks
# 43             Energy drinks
# 44             Energy drinks
# 45             Energy drinks
# 46             Energy drinks
# 47             Energy drinks
# 48             Energy drinks
# 49             Energy drinks
#
#                                                  item           caffeine_mg
# 0                                         Drip brewed     100 mg per 180 ml
# 1                                          Percolated     120 mg per 180 ml
# 2                                             Instant     90 mg. per 180 ml
# 3                                Brewed decaffeinated       5 mg per 180 ml
# 4                               Instant decaffeinated       3 mg per 180 ml
# 5                                               Green      35 mg per 180 ml
# 6                                               Black      70 mg per 180 ml
# 7                                      Canned ice tea  35 mg per 360 oz can
# 8                                     Cocoa beverages      13 mg per 180 ml
# 9                                      Milk chocolate        6 mg per 30 ml
# 10                                   Baking chocolate       35 mg per 30 ml
# 11                                    Small candy bar         25 mg per bar
# 12                   Leading colas (regular and diet)                 45 mg
# 13                                         Dr. Pepper                 40 mg
# 14                                        Mello Yello                 53 mg
# 15                                       Mountain Dew                 54 mg
# 16                                           Mr. Pibb                 41 mg
# 17                                            OK Soda                 40 mg
# 18                                          Jolt Cola                 72 mg
# 19                                             Anacin                 32 mg
# 20      Dristan (i.e., acetylsalicylic acid+caffeine)                 16 mg
# 21      Dexatrim (i.e., phenylpropanolamine+caffeine)                 16 mg
# 22  Excedrin (i.e., acetaminophen+acetylsalicylic ...                200 mg
# 23  Midol (i.e., acetaminophen+pyrilamine maleate+...                 32 mg
# 24                             Nodoz (i.e., caffeine)                100 mg
# 25                           Vivarin (i.e., caffeine)                200 mg
# 26  Vanquish (i.e., acetaminophen+acetylsalicylic ...                 33 mg
# 27                                    28 Energy Drink                 80 mg
# 28                                       6 Hour Power                125 mg
# 29                                  BANG Energy Drink                357 mg
# 30                                 Biggby Iced Coffee                192 mg
# 31                              Caffeine Energy Drink                140 mg
# 32                         Chameleon Cold Brew Coffee               2160 mg
# 33                               Cocaine Energy Drink                280 mg
# 34                                Diablo Energy Drink                 95 mg
# 35                               Guayaki Empower Mint                140 mg
# 36                           Hardcore Energize Bullet                300 mg
# 37                                       Java Monster                188 mg
# 38                                   Liquid Lightning                200 mg
# 39                               Monster Energy Drink                160 mg
# 40                             Neurofuel Energy Drink                128 mg
# 41                                Octane Energy Drink                225 mg
# 42                              Potencia Energy Drink                250 mg
# 43                                       Rage Inferno                375 mg
# 44                                           Red Bull                 80 mg
# 45                                 Speed Energy Drink                186 mg
# 46                              Starbucks Tall Coffee                260 mg
# 47                            Ubermonster Energy Brew                160 mg
# 48                                  Venom Black Mamba                160 mg
# 49                                   Zun Energy Drink                100 mg

# %%
# Converting caffeine values to numeric

for index, row in df.iterrows():
    text = row.caffeine_mg
    num = text.find(' mg')
    num = int(num)
    value = text[0:num]
    row.caffeine_mg = value
df['caffeine_mg'] = pd.to_numeric(df['caffeine_mg'])

# %%
# Changing names to be more useful

df['category'][df.category == 'Coffee (180 ml cup)'] = 'Coffee'
df['category'][df.category == 'Tea (180 ml cup)'] = 'Tea'
df['category'][df.category == 'Cocoa'] = 'Chocolate'
df['category'][df.category == 'Soft drinks (360 ml can)'] = 'Soft Drink'
df['category'][df.category == 'Medications (per tablet)'] = 'Medication'
# Out:
# /Users/mags/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/mags/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /Users/mags/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /Users/mags/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/mags/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
df
# Out:
#                     category  \
# 0        Coffee (180 ml cup)
# 1        Coffee (180 ml cup)
# 2        Coffee (180 ml cup)
# 3        Coffee (180 ml cup)
# 4        Coffee (180 ml cup)
# 5           Tea (180 ml cup)
# 6           Tea (180 ml cup)
# 7           Tea (180 ml cup)
# 8                      Cocoa
# 9                  Chocolate
# 10                 Chocolate
# 11                 Chocolate
# 12  Soft drinks (360 ml can)
# 13  Soft drinks (360 ml can)
# 14  Soft drinks (360 ml can)
# 15  Soft drinks (360 ml can)
# 16  Soft drinks (360 ml can)
# 17  Soft drinks (360 ml can)
# 18  Soft drinks (360 ml can)
# 19  Medications (per tablet)
# 20  Medications (per tablet)
# 21  Medications (per tablet)
# 22  Medications (per tablet)
# 23  Medications (per tablet)
# 24  Medications (per tablet)
# 25  Medications (per tablet)
# 26  Medications (per tablet)
# 27             Energy drinks
# 28             Energy drinks
# 29             Energy drinks
# 30             Energy drinks
# 31             Energy drinks
# 32             Energy drinks
# 33             Energy drinks
# 34             Energy drinks
# 35             Energy drinks
# 36             Energy drinks
# 37             Energy drinks
# 38             Energy drinks
# 39             Energy drinks
# 40             Energy drinks
# 41             Energy drinks
# 42             Energy drinks
# 43             Energy drinks
# 44             Energy drinks
# 45             Energy drinks
# 46             Energy drinks
# 47             Energy drinks
# 48             Energy drinks
# 49             Energy drinks
#
#                                                  item  caffeine_mg
# 0                                         Drip brewed          100
# 1                                          Percolated          120
# 2                                             Instant           90
# 3                                Brewed decaffeinated            5
# 4                               Instant decaffeinated            3
# 5                                               Green           35
# 6                                               Black           70
# 7                                      Canned ice tea           35
# 8                                     Cocoa beverages           13
# 9                                      Milk chocolate            6
# 10                                   Baking chocolate           35
# 11                                    Small candy bar           25
# 12                   Leading colas (regular and diet)           45
# 13                                         Dr. Pepper           40
# 14                                        Mello Yello           53
# 15                                       Mountain Dew           54
# 16                                           Mr. Pibb           41
# 17                                            OK Soda           40
# 18                                          Jolt Cola           72
# 19                                             Anacin           32
# 20      Dristan (i.e., acetylsalicylic acid+caffeine)           16
# 21      Dexatrim (i.e., phenylpropanolamine+caffeine)           16
# 22  Excedrin (i.e., acetaminophen+acetylsalicylic ...          200
# 23  Midol (i.e., acetaminophen+pyrilamine maleate+...           32
# 24                             Nodoz (i.e., caffeine)          100
# 25                           Vivarin (i.e., caffeine)          200
# 26  Vanquish (i.e., acetaminophen+acetylsalicylic ...           33
# 27                                    28 Energy Drink           80
# 28                                       6 Hour Power          125
# 29                                  BANG Energy Drink          357
# 30                                 Biggby Iced Coffee          192
# 31                              Caffeine Energy Drink          140
# 32                         Chameleon Cold Brew Coffee         2160
# 33                               Cocaine Energy Drink          280
# 34                                Diablo Energy Drink           95
# 35                               Guayaki Empower Mint          140
# 36                           Hardcore Energize Bullet          300
# 37                                       Java Monster          188
# 38                                   Liquid Lightning          200
# 39                               Monster Energy Drink          160
# 40                             Neurofuel Energy Drink          128
# 41                                Octane Energy Drink          225
# 42                              Potencia Energy Drink          250
# 43                                       Rage Inferno          375
# 44                                           Red Bull           80
# 45                                 Speed Energy Drink          186
# 46                              Starbucks Tall Coffee          260
# 47                            Ubermonster Energy Brew          160
# 48                                  Venom Black Mamba          160
# 49                                   Zun Energy Drink          100

# %%
df
# Out:
#                     category  \
# 0        Coffee (180 ml cup)
# 1        Coffee (180 ml cup)
# 2        Coffee (180 ml cup)
# 3        Coffee (180 ml cup)
# 4        Coffee (180 ml cup)
# 5           Tea (180 ml cup)
# 6           Tea (180 ml cup)
# 7           Tea (180 ml cup)
# 8                      Cocoa
# 9                  Chocolate
# 10                 Chocolate
# 11                 Chocolate
# 12  Soft drinks (360 ml can)
# 13  Soft drinks (360 ml can)
# 14  Soft drinks (360 ml can)
# 15  Soft drinks (360 ml can)
# 16  Soft drinks (360 ml can)
# 17  Soft drinks (360 ml can)
# 18  Soft drinks (360 ml can)
# 19  Medications (per tablet)
# 20  Medications (per tablet)
# 21  Medications (per tablet)
# 22  Medications (per tablet)
# 23  Medications (per tablet)
# 24  Medications (per tablet)
# 25  Medications (per tablet)
# 26  Medications (per tablet)
# 27             Energy drinks
# 28             Energy drinks
# 29             Energy drinks
# 30             Energy drinks
# 31             Energy drinks
# 32             Energy drinks
# 33             Energy drinks
# 34             Energy drinks
# 35             Energy drinks
# 36             Energy drinks
# 37             Energy drinks
# 38             Energy drinks
# 39             Energy drinks
# 40             Energy drinks
# 41             Energy drinks
# 42             Energy drinks
# 43             Energy drinks
# 44             Energy drinks
# 45             Energy drinks
# 46             Energy drinks
# 47             Energy drinks
# 48             Energy drinks
# 49             Energy drinks
#
#                                                  item  caffeine_mg
# 0                                         Drip brewed          200
# 1                                          Percolated          240
# 2                                             Instant          180
# 3                                Brewed decaffeinated           10
# 4                               Instant decaffeinated            6
# 5                                               Green           35
# 6                                               Black           70
# 7                                      Canned ice tea           35
# 8                                     Cocoa beverages           13
# 9                                      Milk chocolate            6
# 10                                   Baking chocolate           35
# 11                                    Small candy bar           25
# 12                   Leading colas (regular and diet)           45
# 13                                         Dr. Pepper           40
# 14                                        Mello Yello           53
# 15                                       Mountain Dew           54
# 16                                           Mr. Pibb           41
# 17                                            OK Soda           40
# 18                                          Jolt Cola           72
# 19                                             Anacin           32
# 20      Dristan (i.e., acetylsalicylic acid+caffeine)           16
# 21      Dexatrim (i.e., phenylpropanolamine+caffeine)           16
# 22  Excedrin (i.e., acetaminophen+acetylsalicylic ...          200
# 23  Midol (i.e., acetaminophen+pyrilamine maleate+...           32
# 24                             Nodoz (i.e., caffeine)          100
# 25                           Vivarin (i.e., caffeine)          200
# 26  Vanquish (i.e., acetaminophen+acetylsalicylic ...           33
# 27                                    28 Energy Drink           80
# 28                                       6 Hour Power          125
# 29                                  BANG Energy Drink          357
# 30                                 Biggby Iced Coffee          192
# 31                              Caffeine Energy Drink          140
# 32                         Chameleon Cold Brew Coffee         2160
# 33                               Cocaine Energy Drink          280
# 34                                Diablo Energy Drink           95
# 35                               Guayaki Empower Mint          140
# 36                           Hardcore Energize Bullet          300
# 37                                       Java Monster          188
# 38                                   Liquid Lightning          200
# 39                               Monster Energy Drink          160
# 40                             Neurofuel Energy Drink          128
# 41                                Octane Energy Drink          225
# 42                              Potencia Energy Drink          250
# 43                                       Rage Inferno          375
# 44                                           Red Bull           80
# 45                                 Speed Energy Drink          186
# 46                              Starbucks Tall Coffee          260
# 47                            Ubermonster Energy Brew          160
# 48                                  Venom Black Mamba          160
# 49                                   Zun Energy Drink          100

# %%
plt.figure(figsize=(12,12))
plt.barh(df.item, np.log(df.caffeine_mg))
# Out:
# <BarContainer object of 50 artists>

# %%
plt.figure(figsize=(12,12))

plt.barh(df.item, df.caffeine_mg, log=True)
plt.grid()
#plt.xticks(ticks=(range(0, 2500)))
plt.set_loglevel()

# %%
np.logspace(0, 10, 2500)
# Out:
# array([1.00000000e+00, 1.00925661e+00, 1.01859890e+00, ...,
#        9.81740706e+09, 9.90828293e+09, 1.00000000e+10])

# %%
f, ax = plt.subplots(figsize=(20, 14))
ax.set(yscale="log")
ax.grid(alpha = 0.5)
plt.yticks(list(range(0,10, 1))+list(range(10,100, 10))+list(range(100, 1000, 100))+list(range(1000, 2500, 1000)), fontsize=20)
plt.xticks(fontsize=20)
sns.boxplot(x=df.category, y=df.caffeine_mg)
ax.set_xlabel('Category', fontsize=30)
ax.set_ylabel('Caffeine Content (mg)', fontsize=30)
ax.set_title('Caffeine Content of Various \nFoods, Drinks, and Medications', fontsize=40);
ax.scatter(df.category, df.caffeine_mg, color ='black', s = 50)

# %%
plt.figure(figsize=(20, 6))
plt.barh(df[df.category=='Coffee'].item, df[df.category=='Coffee'].caffeine_mg)
#plt.xscale("log")
plt.grid(axis='x', alpha = 0.5)
plt.xticks(list(range(0,100, 10))+list(range(100, 500, 100)));

# %%
# # Scaling drink types to be consistent
# df['caffeine_mg'][df.category == 'Coffee (180 ml cup)'] = df['caffeine_mg']*2
# df['caffeine_mg'][5, 6] = df['caffeine_mg']*2
# df['caffeine_mg'][df.category == 'Soft drinks (360 ml can)'] = df['caffeine_mg']*2

# %%
names = ['Kai', 'Marg', 'Laura', 'Patrick', 'Antony']
random.shuffle(names)
names
# Out:
# ['Laura', 'Patrick', 'Marg', 'Antony', 'Kai']
